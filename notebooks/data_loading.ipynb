# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "mysql+pymysql://root:password@localhost/dmart_cg_db"
)

files = {
    "dim_stores":       "data/dim_stores.csv",
    "dim_products":     "data/dim_products.csv",
    "fact_sales":       "data/fact_sales.csv",
    "fact_sale_items":  "data/fact_sale_items.csv",
}

for table_name, file_name in files.items():
    df = pd.read_csv(file_name)
    df.to_sql(table_name, con=engine, if_exists="replace", index=False)
    print(f"Loaded {table_name}: {len(df):,} rows")
# Out:
# Loaded dim_stores: 6 rows
# Loaded dim_products: 205 rows
# Loaded fact_sales: 882,037 rows
# Loaded fact_sale_items: 5,833,867 rows
